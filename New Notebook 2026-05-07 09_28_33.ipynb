-- %%
%python
dbutils.fs.cp(
    "s3://sneha-retail-sales-data-warehouse/sftp/customers/",
    "s3://sneha-retail-sales-data-warehouse/raw/customers/",
    True
)

dbutils.fs.cp(
    "s3://sneha-retail-sales-data-warehouse/sftp/products/",
    "s3://sneha-retail-sales-data-warehouse/raw/products/",
    True
)

dbutils.fs.cp(
    "s3://sneha-retail-sales-data-warehouse/sftp/stores/",
    "s3://sneha-retail-sales-data-warehouse/raw/stores/",
    True
)

dbutils.fs.cp(
    "s3://sneha-retail-sales-data-warehouse/sftp/sales/",
    "s3://sneha-retail-sales-data-warehouse/raw/sales/",
    True
)

print("RAW zone populated")
